# %% [markdown]
# # Import Required Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from tabulate import tabulate
from IPython.display import display, HTML
import ipywidgets as widgets
import panel as pn

# %% [markdown]
# # Load Dataset

# %%
# Load the cleaned movies dataframe
movies_df = pd.read_csv("../data/processed-data/movies_cleaned.csv")

pd.set_option("display.max_columns", None)
movies_df.head(3)
# Out:
#      IMDB_ID            Title  Year Release_Date Release_Month Age_Rating  \
# 0  tt0097499          henry v  1989   1989-10-05       October      pg-13
# 1  tt1320253  the expendables  2010   2010-08-03        August          r
# 2  tt1025100       gemini man  2019   2019-10-02       October      pg-13
#
#                                             Overview  \
# 0  gritty adaption william shakespeares play engl...
# 1  barney ross leads band highly skilled mercenar...
# 2  henry brogan elite 51 year assassin whos ready...
#
#                                             Keywords     Genre  \
# 0  ['france kingdom theater play based on true st...       war
# 1  ['rescue sniper island martial arts tattoo esc...  thriller
# 2                                   ['hitman clone']  thriller
#
#              Director                                             Actors  \
# 0     kenneth branagh    ['kenneth branagh derek jacobi simon shepherd']
# 1  sylvester stallone        ['sylvester stallone jason statham jet li']
# 2             ang lee  ['will smith mary elizabeth winstead clive owen']
#
#    Runtime  Metascore_Rating  IMDB_Rating  Rotten_Tomatoes_Rating  \
# 0      137               8.3          7.5                     9.8
# 1      103               4.5          6.4                     4.2
# 2      117               3.8          5.7                     2.7
#
#    TMDB_Rating  Average_Rating  Won_Award  Oscar_Wins  Oscar_Nominations  \
# 0          7.2           8.200       True           1                  0
# 1          6.2           5.325      False           0                  0
# 2          6.3           4.625      False           0                  0
#
#       Budget  Budget_Normalized    Revenue  Revenue_Normalized  \
# 0    9000000          -0.873465   10200000           -0.801446
# 1   80000000           0.317499  274470394            0.188250
# 2  140000000           1.323948  173469516           -0.189999
#
#    Return_On_Investment  Popularity
# 0              1.133333      18.771
# 1              3.430880      74.573
# 2              1.239068      27.266

# %% [markdown]
# # Clean the Dataset

# %%
# Remove brakcets and apostrophes from the Actors column
movies_df["Actors"] = movies_df["Actors"].str.replace("[", "", regex = False).str.replace("]", "", regex = False).str.replace("'", "", regex = False)
movies_df["Keywords"] = movies_df["Keywords"].str.replace("[", "", regex = False).str.replace("]", "", regex = False).str.replace("'", "", regex = False)

# Drop columns that won't be included in the cosine similarity calculation
columns_to_drop = ["IMDB_ID", "Keywords", "Won_Award", "Release_Date", "Release_Month", "Age_Rating", "Budget_Normalized", "Revenue_Normalized", "Metascore_Rating", "IMDB_Rating", "Rotten_Tomatoes_Rating", "TMDB_Rating"]
filtered_movies_df = movies_df.drop(columns = columns_to_drop)

# PReview the new dataframe
filtered_movies_df.head(3)
# Out:
#              Title  Year                                           Overview  \
# 0          henry v  1989  gritty adaption william shakespeares play engl...
# 1  the expendables  2010  barney ross leads band highly skilled mercenar...
# 2       gemini man  2019  henry brogan elite 51 year assassin whos ready...
#
#       Genre            Director  \
# 0       war     kenneth branagh
# 1  thriller  sylvester stallone
# 2  thriller             ang lee
#
#                                           Actors  Runtime  Average_Rating  \
# 0    kenneth branagh derek jacobi simon shepherd      137           8.200
# 1        sylvester stallone jason statham jet li      103           5.325
# 2  will smith mary elizabeth winstead clive owen      117           4.625
#
#    Oscar_Wins  Oscar_Nominations     Budget    Revenue  Return_On_Investment  \
# 0           1                  0    9000000   10200000              1.133333
# 1           0                  0   80000000  274470394              3.430880
# 2           0                  0  140000000  173469516              1.239068
#
#    Popularity
# 0      18.771
# 1      74.573
# 2      27.266

# %% [markdown]
# ## Compute TD-IDF and Cosine Similarity Scores for Text Data

# %%
# Combine all text features of each movie into one value of a new column
filtered_movies_df["combined_text_features"] = filtered_movies_df["Overview"] + " " + filtered_movies_df["Genre"] + " " + filtered_movies_df["Director"] + " " + filtered_movies_df["Actors"]

# Create a TF-IDF matrix to vectorize words for each movie's text features
vectorizer = TfidfVectorizer(max_features = 5000, 
                             ngram_range = (1, 2),
                             min_df = 2,
                             max_df = 0.95)
tfidf_matrix = vectorizer.fit_transform(filtered_movies_df["combined_text_features"])

# Calculate textual cosine similarity scores for each movie
text_cos_similarity = cosine_similarity(tfidf_matrix)

# %% [markdown]
# ## Compute Cosine Similarity Scores for Numerical Data

# %%
# Filter the df to only include numerical columns
numerical_features = ["Runtime", "Runtime", "Average_Rating", "Oscar_Wins", "Return_On_Investment", 
                      "Budget", "Revenue", "Popularity"]

# Scale the values so that one column does not have an extreme bias towards the cosine similarity scores
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(filtered_movies_df[numerical_features])

# Calculate numerical cosine similarity scores for each movie
numerical_cos_similarity = cosine_similarity(scaled_features)

# %% [markdown]
# ## Determine Cosine Similarity Score Weights for Each Datatype

# %%
# Set weights for each cosine similarity scores to determine whether text or numerical data has more say in the recommendations
text_weight = 0.25
numerical_weight = 0.75

# Create a combined cosine similarity score that uses both text and numerical features
combined_similarity = text_weight * text_cos_similarity + numerical_weight * numerical_cos_similarity


# Function to take in a movie and genreate 10 movies that are most similar to it
def recommend_movies(movie_title, top_n = 10):    
    # Obtain the index of the given movie
    selected_movie_index = filtered_movies_df[filtered_movies_df["Title"] == movie_title].index[0]

    # Obtain the similarity scores for the selected movie and place them in a list, along with each movie's index
    sim_scores = list(enumerate(combined_similarity[selected_movie_index]))

    # Sort movies based on similarity scores
    sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse = True)

    # Filter the list down to n movies with the highest similiarty scores (excluding the first index/selected movie)
    sim_scores = sim_scores[0:top_n + 1]

    # Get indices of the top-n similar movies
    movie_indices = [i[0] for i in sim_scores]
    movie_scores = [i[1].round(4) for i in sim_scores]
    
    # Create a new recommended movie df with selected features of the top movies by matching the indeces of the recommended movies
    columns_to_keep = ["IMDB_ID", "Title", "Year", "Age_Rating", "Genre", "Keywords", "Director", "Actors", "Average_Rating", "Revenue", "Budget", "Oscar_Wins"]

    recommendations_df = movies_df[columns_to_keep]
    recommendations_df = recommendations_df.iloc[movie_indices]
    recommendations_df["Similarity_Score"] = movie_scores

    # Return the top-n similar movies
    return recommendations_df

# %% [markdown]
# # Example

# %%
pd.set_option("display.max_rows", None)

selected_movie = "the da vinci code"
recommendations = recommend_movies(selected_movie, 1500).reset_index(drop = True)

recommendations = recommendations[["Title", "Year", "Age_Rating", "Genre", "Director", "Average_Rating", "Similarity_Score"]].reset_index(drop = True)
recommendations.index = recommendations.index + 1

recommendations.insert(0, "Rank", recommendations.index)


recommendations.head(100)
# Out:
#      Rank                                        Title  Year Age_Rating  \
# 1       1                            the da vinci code  2006      pg-13
# 2       2                               angels  demons  2009      pg-13
# 3       3                                      inferno  2016      pg-13
# 4       4                                 far and away  1992      pg-13
# 5       5                                         2012  2009      pg-13
# 6       6                      jurassic world dominion  2022      pg-13
# 7       7        the league of extraordinary gentlemen  2003      pg-13
# 8       8                                         troy  2004          r
# 9       9                                      flyboys  2006      pg-13
# 10     10                transformers dark of the moon  2011      pg-13
# 11     11                     the amazing spider man 2  2014      pg-13
# 12     12                            national treasure  2004         pg
# 13     13                                    insurgent  2015      pg-13
# 14     14                                        elvis  2022      pg-13
# 15     15                              assassins creed  2016      pg-13
# 16     16                                   the batman  2022      pg-13
# 17     17             the hobbit an unexpected journey  2012      pg-13
# 18     18                            the bounty hunter  2010      pg-13
# 19     19                                    backdraft  1991          r
# 20     20                          fifty shades darker  2017          r
# 21     21                                    the mummy  2017      pg-13
# 22     22                               holmes  watson  2018      pg-13
# 23     23     star wars episode i   the phantom menace  1999         pg
# 24     24                                  deep impact  1998      pg-13
# 25     25                                  end of days  1999          r
# 26     26                                 transformers  2007      pg-13
# 27     27                        gone in sixty seconds  2000      pg-13
# 28     28                              couples retreat  2009      pg-13
# 29     29  star wars episode ii   attack of the clones  2002         pg
# 30     30                                 the smurfs 2  2013         pg
# 31     31                            the expendables 3  2014      pg-13
# 32     32                                vampires suck  2010      pg-13
# 33     33                               valentines day  2010      pg-13
# 34     34                                    zookeeper  2011         pg
# 35     35  lara croft tomb raider   the cradle of life  2003      pg-13
# 36     36                                  grown ups 2  2013      pg-13
# 37     37                        exodus gods and kings  2014      pg-13
# 38     38                       exorcist the beginning  2004          r
# 39     39                                    allegiant  2016      pg-13
# 40     40            national treasure book of secrets  2007         pg
# 41     41                   kingsman the golden circle  2017          r
# 42     42     the twilight saga breaking dawn   part 1  2011      pg-13
# 43     43                        beverly hills cop iii  1994          r
# 44     44                   killers of the flower moon  2023          r
# 45     45                            the mummy returns  2001      pg-13
# 46     46           transformers revenge of the fallen  2009      pg-13
# 47     47                                   striptease  1996          r
# 48     48                                        congo  1995      pg-13
# 49     49                        the dark knight rises  2012      pg-13
# 50     50   fantastic beasts the secrets of dumbledore  2022      pg-13
# 51     51                                      aquaman  2018      pg-13
# 52     52                               batman forever  1995      pg-13
# 53     53             i now pronounce you chuck  larry  2007      pg-13
# 54     54                           terminator genisys  2015      pg-13
# 55     55                             now you see me 2  2016      pg-13
# 56     56                                      spectre  2015      pg-13
# 57     57                             sex and the city  2008          r
# 58     58           the hobbit the desolation of smaug  2013      pg-13
# 59     59                 the lost world jurassic park  1997      pg-13
# 60     60                                     baywatch  2017          r
# 61     61                                   fools gold  2008      pg-13
# 62     62                              just go with it  2011      pg-13
# 63     63                               no time to die  2021      pg-13
# 64     64                                    abduction  2011      pg-13
# 65     65                              die another day  2002      pg-13
# 66     66                       the day after tomorrow  2004      pg-13
# 67     67                                      taken 3  2014      pg-13
# 68     68                                eat pray love  2010      pg-13
# 69     69                       the wandering earth ii  2023         nr
# 70     70                                lost in space  1998      pg-13
# 71     71                                       pixels  2015      pg-13
# 72     72                                    divergent  2014      pg-13
# 73     73                maze runner the scorch trials  2015      pg-13
# 74     74                                     cocktail  1988          r
# 75     75                black panther wakanda forever  2022      pg-13
# 76     76                     the phantom of the opera  2004      pg-13
# 77     77      harry potter and the chamber of secrets  2002         pg
# 78     78                    the twilight saga eclipse  2010      pg-13
# 79     79                           planet of the apes  2001      pg-13
# 80     80                      the wolf of wall street  2013          r
# 81     81                                       sliver  1993          r
# 82     82       harry potter and the half blood prince  2009         pg
# 83     83         the mummy tomb of the dragon emperor  2008      pg-13
# 84     84       pirates of the caribbean at worlds end  2007      pg-13
# 85     85                           big mommas house 2  2006      pg-13
# 86     86                             meet the fockers  2004      pg-13
# 87     87                   men in black international  2019      pg-13
# 88     88                             perfect stranger  2007          r
# 89     89                                          xxx  2002      pg-13
# 90     90                             the green hornet  2011      pg-13
# 91     91       the messenger the story of joan of arc  1999          r
# 92     92                                  ghost rider  2007      pg-13
# 93     93                                     warcraft  2016      pg-13
# 94     94                                         hulk  2003      pg-13
# 95     95                godzilla king of the monsters  2019      pg-13
# 96     96              big mommas like father like son  2011      pg-13
# 97     97                                  vanilla sky  2001          r
# 98     98                                  king arthur  2004      pg-13
# 99     99                                  point break  2015      pg-13
# 100   100                           sex and the city 2  2010          r
#
#                Genre                        Director  Average_Rating  \
# 1           thriller                      ron howard           5.100
# 2           thriller                      ron howard           5.450
# 3            mystery                      ron howard           4.700
# 4            romance                      ron howard           5.825
# 5             action                 roland emmerich           5.125
# 6    science fiction                 colin trevorrow           4.750
# 7    science fiction              stephen norrington           4.100
# 8                war               wolfgang petersen           6.350
# 9                war                       tony bill           5.300
# 10   science fiction                     michael bay           5.025
# 11            action                       marc webb           5.850
# 12            action                  jon turteltaub           5.525
# 13          thriller                robert schwentke           4.925
# 14             drama                    baz luhrmann           7.225
# 15   science fiction                   justin kurzel           4.125
# 16          thriller                     matt reeves           7.800
# 17            action                   peter jackson           6.850
# 18           romance                    andy tennant           3.725
# 19          thriller                      ron howard           6.125
# 20             drama                     james foley           3.875
# 21          thriller                   alex kurtzman           3.950
# 22           mystery                      etan cohen           2.900
# 23   science fiction                    george lucas           5.850
# 24            action                      mimi leder           5.225
# 25           fantasy                     peter hyams           4.075
# 26   science fiction                     michael bay           6.425
# 27          thriller                    dominic sena           4.750
# 28           romance               peter billingsley           3.600
# 29            action                    george lucas           6.275
# 30            comedy                    raja gosnell           3.975
# 31          thriller                  patrick hughes           4.750
# 32           fantasy  jason friedberg, aaron seltzer           2.475
# 33            comedy                  garry marshall           4.200
# 34           romance                    frank coraci           3.750
# 35          thriller                     jan de bont           4.475
# 36            comedy                    dennis dugan           3.550
# 37            action                    ridley scott           5.025
# 38           mystery                    renny harlin           3.650
# 39           mystery                robert schwentke           4.050
# 40          thriller                  jon turteltaub           5.300
# 41            action                  matthew vaughn           5.800
# 42           fantasy                     bill condon           4.550
# 43             crime                     john landis           3.500
# 44             drama                 martin scorsese           8.300
# 45           fantasy                 stephen sommers           5.550
# 46            action                     michael bay           4.400
# 47             crime                  andrew bergman           3.800
# 48   science fiction                  frank marshall           3.825
# 49            action               christopher nolan           8.175
# 50           fantasy                     david yates           5.550
# 51            action                       james wan           6.450
# 52            action                 joel schumacher           5.000
# 53            comedy                    dennis dugan           4.300
# 54            action                     alan taylor           4.650
# 55             crime                      jon m. chu           5.300
# 56          thriller                      sam mendes           6.400
# 57            comedy            michael patrick king           5.650
# 58           fantasy                   peter jackson           7.350
# 59            action                steven spielberg           6.075
# 60             crime                     seth gordon           4.275
# 61           romance                    andy tennant           3.850
# 62           romance                    dennis dugan           4.575
# 63          thriller              cary joji fukunaga           7.450
# 64           mystery                  john singleton           3.500
# 65            action                    lee tamahori           5.800
# 66            action                 roland emmerich           5.550
# 67            action                 olivier megaton           4.050
# 68           romance                     ryan murphy           5.125
# 69   science fiction                       frant gwo           6.975
# 70   science fiction                 stephen hopkins           4.375
# 71   science fiction                  chris columbus           3.950
# 72            action                     neil burger           5.600
# 73            action                        wes ball           5.550
# 74             drama                 roger donaldson           3.525
# 75            action                    ryan coogler           7.225
# 76             drama                 joel schumacher           5.450
# 77           fantasy                  chris columbus           7.400
# 78           fantasy                     david slade           5.425
# 79            action                      tim burton           5.200
# 80             drama                 martin scorsese           7.900
# 81          thriller                   phillip noyce           4.050
# 82           fantasy                     david yates           7.850
# 83            action                       rob cohen           3.775
# 84            action                  gore verbinski           5.925
# 85             crime                  john whitesell           3.625
# 86            comedy                       jay roach           5.100
# 87            comedy                    f. gary gray           4.400
# 88           mystery                     james foley           3.875
# 89            action                       rob cohen           5.325
# 90            action                   michel gondry           4.950
# 91               war                      luc besson           5.325
# 92            action             mark steven johnson           4.300
# 93            action                    duncan jones           4.800
# 94   science fiction                         ang lee           5.725
# 95            action               michael dougherty           5.425
# 96             crime                  john whitesell           3.175
# 97          thriller                   cameron crowe           5.600
# 98               war                   antoine fuqua           5.050
# 99             crime                    ericson core           3.950
# 100          romance            michael patrick king           3.725
#
#      Similarity_Score
# 1              1.0000
# 2              0.8119
# 3              0.8016
# 4              0.7528
# 5              0.7498
# 6              0.7497
# 7              0.7452
# 8              0.7447
# 9              0.7443
# 10             0.7439
# 11             0.7436
# 12             0.7433
# 13             0.7431
# 14             0.7420
# 15             0.7406
# 16             0.7399
# 17             0.7396
# 18             0.7391
# 19             0.7391
# 20             0.7390
# 21             0.7377
# 22             0.7375
# 23             0.7375
# 24             0.7369
# 25             0.7368
# 26             0.7365
# 27             0.7364
# 28             0.7363
# 29             0.7363
# 30             0.7360
# 31             0.7359
# 32             0.7354
# 33             0.7353
# 34             0.7352
# 35             0.7352
# 36             0.7351
# 37             0.7349
# 38             0.7348
# 39             0.7348
# 40             0.7347
# 41             0.7346
# 42             0.7344
# 43             0.7339
# 44             0.7338
# 45             0.7336
# 46             0.7335
# 47             0.7333
# 48             0.7331
# 49             0.7330
# 50             0.7330
# 51             0.7329
# 52             0.7326
# 53             0.7323
# 54             0.7323
# 55             0.7320
# 56             0.7317
# 57             0.7316
# 58             0.7314
# 59             0.7312
# 60             0.7307
# 61             0.7305
# 62             0.7304
# 63             0.7303
# 64             0.7301
# 65             0.7300
# 66             0.7298
# 67             0.7296
# 68             0.7294
# 69             0.7293
# 70             0.7292
# 71             0.7291
# 72             0.7287
# 73             0.7286
# 74             0.7286
# 75             0.7286
# 76             0.7285
# 77             0.7285
# 78             0.7283
# 79             0.7281
# 80             0.7279
# 81             0.7279
# 82             0.7277
# 83             0.7277
# 84             0.7277
# 85             0.7276
# 86             0.7272
# 87             0.7272
# 88             0.7272
# 89             0.7272
# 90             0.7267
# 91             0.7263
# 92             0.7262
# 93             0.7261
# 94             0.7260
# 95             0.7260
# 96             0.7258
# 97             0.7257
# 98             0.7257
# 99             0.7255
# 100            0.7253

# %%
recommendations.to_csv("../website/movie_guesser_dfs/da_vinci_code.csv", index = False)

# %%
# Convert to JSON format (list of dicts)
json_data = recommendations.to_json(orient="records", indent=2)

# Save to a JSON file
with open("../website/movie_guesser_dfs/da_vinci_code.json", "w") as f:
    f.write(json_data)
